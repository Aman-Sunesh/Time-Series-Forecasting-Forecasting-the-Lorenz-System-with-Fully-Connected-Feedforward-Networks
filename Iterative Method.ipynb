# %%
import re
import sys
import io
import numpy as np
import itertools
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import pandas as pd
from copy import deepcopy
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# !pip install nolds
import nolds
# Out:
# Requirement already satisfied: nolds in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.6.1)
# Requirement already satisfied: numpy<3.0,>1.0 in /home/codespace/.local/lib/python3.12/site-packages (from nolds) (2.2.4)
# Requirement already satisfied: future in /usr/local/python/3.12.1/lib/python3.12/site-packages (from nolds) (1.0.0)
# Requirement already satisfied: setuptools in /home/codespace/.local/lib/python3.12/site-packages (from nolds) (76.0.0)
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %% [markdown]
# # Synthetic Data Generation

# %%
def Lorentz_System(state, sigma, rho, beta):
    x, y, z = state
    x_dot = sigma*(y-x)
    y_dot = x*(rho-z) - y
    z_dot = x*y - beta*z

    return np.array([x_dot, y_dot, z_dot])

# %% [markdown]
# ### Runga Kutta

# %%
def rk4(state, dt, sigma, rho, beta):
    k1 = Lorentz_System(state, sigma, rho, beta)
    k2 = Lorentz_System(state + 0.5 * dt * k1, sigma, rho, beta)
    k3 = Lorentz_System(state + 0.5 * dt * k2, sigma, rho, beta)
    k4 = Lorentz_System(state + dt * k3, sigma, rho, beta)

    return state + (dt*((k1 + 2*k2 + 2*k3 + k4)/6.0))

# %% [markdown]
# Now, let's visualize the Lorenz attractor using N = 50,000

# %%
dt = 0.01
N = 50000
sigma, rho, beta = 10.0, 28.0, 8.0/3.0
x0, y0, z0 = 1.0, 1.0, 1.0
state = np.array([x0, y0, z0])

trajectory = np.empty((N+1, 3))
trajectory[0] = state

for i in range(1, N+1):
    state = rk4(state, dt, sigma, rho, beta)
    trajectory[i] = state

# %%
# Subsample trajectory to plot fewer points
thin = trajectory[::1]

fig = plt.figure(figsize=(20, 5))

# 3D
ax0 = fig.add_subplot(1, 4, 1, projection='3d')
ax0.plot(thin[:, 0], thin[:, 1], thin[:, 2], lw=0.5)
ax0.set_xlabel('x(t)'); ax0.set_ylabel('y(t)'); ax0.set_zlabel('z(t)')
ax0.set_title('3D View')
ax0.set_box_aspect((1,1,1))  # equal aspect in 3D

# XY
ax1 = fig.add_subplot(1, 4, 2)
ax1.plot(thin[:, 0], thin[:, 1], lw=0.5)
ax1.set_xlabel('x(t)'); ax1.set_ylabel('y(t)')
ax1.set_title('XY Projection')
ax1.set_aspect('equal', 'box')

# YZ
ax2 = fig.add_subplot(1, 4, 3)
ax2.plot(thin[:, 1], thin[:, 2], lw=0.5)
ax2.set_xlabel('y(t)'); ax2.set_ylabel('z(t)')
ax2.set_title('YZ Projection')
ax2.set_aspect('equal', 'box')

# XZ
ax3 = fig.add_subplot(1, 4, 4)
ax3.plot(thin[:, 0], thin[:, 2], lw=0.5)
ax3.set_xlabel('x(t)'); ax3.set_ylabel('z(t)')
ax3.set_title('XZ Projection')
ax3.set_aspect('equal', 'box')

plt.tight_layout()

# %%
plt.plot(trajectory[-1000::5,0], 'o-')

# %%
print("First point of full trajectory:", trajectory[0])
print("Second point of full trajectory:", trajectory[1])
print("Third point of full trajectory:", trajectory[2])
# Out:
# First point of full trajectory: [1. 1. 1.]
# Second point of full trajectory: [1.01256719 1.2599178  0.98489097]
# Third point of full trajectory: [1.04882371 1.52399713 0.97311422]

# %% [markdown]
# # Feed Forward Neural Network

# %%
def make_windows(trajectory, window_size, horizon = 1):
    # horizon is the number of steps ahead to predict

    N = trajectory.shape[0]
    X, y = [], []

    for i in range(N - window_size - horizon + 1):
        X.append((trajectory[i : i + window_size]).flatten())
        y.append((trajectory[i + window_size : i + window_size + horizon]).flatten())

    return np.array(X), np.array(y)

# %% [markdown]
# # Neural Network Class

# %%
class NeuralNetwork:
    def __init__(self, input_size = 64, hidden_size = 30, output_size = 10, learning_rate = 1e-3, epochs = 1000):
        # Hyperparameters
        self.learning_rate = learning_rate
        self.epochs = epochs
        
        # Weights & bias initialization with small random values
        self.W1 = np.random.randn(input_size, hidden_size) * 0.01  
        self.b1 = np.zeros((1, hidden_size))                       
        self.W2 = np.random.randn(hidden_size, output_size) * 0.01 
        self.b2 = np.zeros((1, output_size))                       #

    # ReLU activation function
    def ReLU(self, x):
        return np.maximum(0, x)

    # Derivative of the ReLU function
    def ReLU_deriv(self, x):
        return np.where(x > 0, 1, 0)

    # Linear Activation Function
    def Linear(self, x):
        return x

    def Linear_deriv(self, x):
        return np.ones_like(x)

    # Forward propagation: computes the activations for the hidden and output layers
    def forward_propagation(self, x):
        # Hidden layer
        self.z1 = x @ self.W1 + self.b1
        self.a1 = self.ReLU(self.z1)
    
        # Output layer
        self.z2 = self.a1 @ self.W2 + self.b2
        self.a2 = self.Linear(self.z2)
        
        return self.a2

    # Compute the cost using Mean Squared Error
    def compute_cost(self, y_pred, y_true):
        return np.mean((y_pred - y_true)**2)

    # Back propagation: computes gradients for updating weights and biases
    def back_propagation(self, x, y):       
        m = y.shape[0]
    
        # Compute error at output layer
        error2 = 2 * (self.a2 - y) * self.Linear_deriv(self.z2)

        # Compute gradients for weights and biases for the output layer
        grad_W2 = (self.a1.T @ error2) / m
        grad_b2 = np.sum(error2, axis = 0, keepdims = True) / m

        # Backpropagate the error to the hidden layer
        error1 = (error2 @ self.W2.T) * self.ReLU_deriv(self.z1)

        # Compute gradients for weights and biases for the hidden layer
        grad_W1 = (x.T @ error1) / m
        grad_b1 = np.sum(error1, axis = 0, keepdims = True) / m

        return grad_W1, grad_b1, grad_W2, grad_b2

    # Update the network parameters (weights and biases) using the computed gradients
    def update_parameters(self, grad_W1, grad_b1, grad_W2, grad_b2):
        self.W2 = self.W2 - (self.learning_rate * grad_W2)
        self.b2 = self.b2 - (self.learning_rate * grad_b2)
        self.W1 = self.W1 - (self.learning_rate * grad_W1)
        self.b1 = self.b1 - (self.learning_rate * grad_b1)

    # Train the neural network by iterating over epochs
    def train(self, x, y, optimizer='sgd'):
        optimizer = optimizer.lower()
        
        if optimizer not in ('sgd', 'adam'):
            raise ValueError("Optimizer must be 'sgd' or 'adam'")

        # Adam hyperparameters
        if optimizer == 'adam':
            beta1, beta2 = 0.9, 0.999
            eps = 1e-8
            # Initialize 1st & 2nd moment vectors
            m_W1 = np.zeros_like(self.W1); v_W1 = np.zeros_like(self.W1)
            m_b1 = np.zeros_like(self.b1); v_b1 = np.zeros_like(self.b1)
            m_W2 = np.zeros_like(self.W2); v_W2 = np.zeros_like(self.W2)
            m_b2 = np.zeros_like(self.b2); v_b2 = np.zeros_like(self.b2)

        for epoch in range(1, self.epochs + 1):
            # Perform forward propagation to get outputs
            Y_pred = self.forward_propagation(x)

            # Compute gradients via back propagation
            grad_W1, grad_b1, grad_W2, grad_b2 = self.back_propagation(x, y)

            if optimizer == 'sgd':
                # Update network parameters with the gradients using Standard SGD
                self.update_parameters(grad_W1, grad_b1, grad_W2, grad_b2)

            else:
                # Adam updates
                m_W1 = beta1 * m_W1 + (1 - beta1) * grad_W1
                v_W1 = beta2 * v_W1 + (1 - beta2) * (grad_W1 ** 2)
                m_b1 = beta1 * m_b1 + (1 - beta1) * grad_b1
                v_b1 = beta2 * v_b1 + (1 - beta2) * (grad_b1 ** 2)
                m_W2 = beta1 * m_W2 + (1 - beta1) * grad_W2
                v_W2 = beta2 * v_W2 + (1 - beta2) * (grad_W2 ** 2)
                m_b2 = beta1 * m_b2 + (1 - beta1) * grad_b2
                v_b2 = beta2 * v_b2 + (1 - beta2) * (grad_b2 ** 2)

                # Bias-corrected moments
                mW1_hat = m_W1 / (1 - beta1 ** epoch)
                vW1_hat = v_W1 / (1 - beta2 ** epoch)
                mb1_hat = m_b1 / (1 - beta1 ** epoch)
                vb1_hat = v_b1 / (1 - beta2 ** epoch)
                mW2_hat = m_W2 / (1 - beta1 ** epoch)
                vW2_hat = v_W2 / (1 - beta2 ** epoch)
                mb2_hat = m_b2 / (1 - beta1 ** epoch)
                vb2_hat = v_b2 / (1 - beta2 ** epoch)

                # Update parameters
                self.W1 -= self.learning_rate * mW1_hat / (np.sqrt(vW1_hat) + eps)
                self.b1 -= self.learning_rate * mb1_hat / (np.sqrt(vb1_hat) + eps)
                self.W2 -= self.learning_rate * mW2_hat / (np.sqrt(vW2_hat) + eps)
                self.b2 -= self.learning_rate * mb2_hat / (np.sqrt(vb2_hat) + eps)

            # Every 100 epochs, compute and print the cost for monitoring convergence
            if (epoch%100 == 0):
                cost = self.compute_cost(Y_pred, y)
                print(f"Epoch {epoch}, Cost: {cost:.6f}, Optimizer: {optimizer.upper()}")

    # Predict class labels for input data
    def predict(self, x):
        return self.forward_propagation(x)

# %% [markdown]
# # Training the Neural Network

# %%
window_size = 20
horizon     = 1

X, y = make_windows(trajectory, window_size, horizon)

# %% [markdown]
# ### Splitting into Training, Validation, and Test Set

# %%
n = X.shape[0]
n_train = int(0.70*n)
n_val   = int(0.15*n)

X_train, y_train = X[:n_train], y[:n_train]
X_val,   y_val   = X[n_train:n_train+n_val], y[n_train:n_train+n_val]
X_test,  y_test  = X[n_train+n_val:], y[n_train+n_val:]

# %%
print(f"Total points: {N}")
print(f"  Training : {X_train.shape[0]} samples")
print(f"  Validation: {X_val.shape[0]} samples")
print(f"  Testing  : {X_test.shape[0]} samples")
# Out:
# Total points: 50000
#   Training : 34986 samples
#   Validation: 7497 samples
#   Testing  : 7498 samples

# %% [markdown]
# ### Normalizing the Data Points

# %%
eps = 1e-8   # Added to standard deviation values to avoid division by zero error
Xmu,  Xstd  = X_train.mean(0, keepdims=True), X_train.std(0, keepdims=True) + eps
ymu,  ystd  = y_train.mean(0, keepdims=True), y_train.std(0, keepdims=True) + eps

X_train = (X_train - Xmu)/Xstd
X_val   = (X_val   - Xmu)/Xstd
X_test  = (X_test  - Xmu)/Xstd

y_train = (y_train - ymu)/ystd
y_val   = (y_val   - ymu)/ystd
y_test  = (y_test  - ymu)/ystd

# %%
model = NeuralNetwork(
    input_size    = window_size * 3,
    hidden_size   = 30,
    output_size   = horizon * 3,
    learning_rate = 1e-3,
    epochs        = 1000 
)

model.train(X_train, y_train)
# Out:
# Epoch 100, Cost: 0.980136, Optimizer: SGD
# Epoch 200, Cost: 0.914167, Optimizer: SGD
# Epoch 300, Cost: 0.717891, Optimizer: SGD
# Epoch 400, Cost: 0.467407, Optimizer: SGD
# Epoch 500, Cost: 0.351306, Optimizer: SGD
# Epoch 600, Cost: 0.291584, Optimizer: SGD
# Epoch 700, Cost: 0.232545, Optimizer: SGD
# Epoch 800, Cost: 0.171888, Optimizer: SGD
# Epoch 900, Cost: 0.119958, Optimizer: SGD
# Epoch 1000, Cost: 0.083472, Optimizer: SGD

# %%
y_hat_val = model.predict(X_val)*ystd + ymu
mse_val   = np.mean((y_hat_val - (y_val*ystd + ymu))**2)
print("Validation MSE:", mse_val)
# Out:
# Validation MSE: 6.2573567612922405

# %% [markdown]
# Typical x, y, z values on the attractor are roughly in the range [-20, 40]. RMSE = sqrt(MSE) = 2.55. So, on average, each coordinate is off by ≈ 2.5 units one time-step (Δt=0.01) into the future.

# %% [markdown]
# # Hyperparameter Tuning using Grid Search

# %%
# Grid of candidates
param_grid = {
    'window_size': [10, 15, 20, 30],
    'hidden_size': [50, 100, 200],
    'learning_rate': [1e-3, 1e-2],
    'optimizer': ['sgd', 'adam']
}

best_mse    = float('inf')
best_params = None
best_model  = None
best_hist   = None

# %%
for combo in itertools.product(*param_grid.values()):
    params = dict(zip(param_grid.keys(), combo))
    X_train_w, y_train_w = make_windows(trajectory[:n_train], params['window_size'])
    X_val_w, y_val_w   = make_windows(trajectory[n_train:n_train+n_val], params['window_size'])

    model = NeuralNetwork(
        input_size    = params['window_size'] * 3,
        hidden_size   = params['hidden_size'],
        output_size   = 3,                     
        learning_rate = params['learning_rate'],
    )
    
    history = model.train(
        X_train_w, y_train_w,
        optimizer = params['optimizer'],
    )

    val_pred = model.predict(X_val_w)
    val_mse  = np.mean((val_pred - y_val_w)**2)

    print(f"Params={params}  →  Val MSE={val_mse:.4e}")
    
    if val_mse < best_mse:
        best_mse    = val_mse
        best_params = params
        best_model  = deepcopy(model)
        best_hist   = history

print("\nBest params:", best_params)
print("Best validation MSE:", best_mse)
# Out:
# Epoch 100, Cost: 207.128491, Optimizer: SGD
# Epoch 200, Cost: 162.645192, Optimizer: SGD
# Epoch 300, Cost: 132.838280, Optimizer: SGD
# Epoch 400, Cost: 112.864669, Optimizer: SGD
# Epoch 500, Cost: 99.479468, Optimizer: SGD
# Epoch 600, Cost: 90.506933, Optimizer: SGD
# Epoch 700, Cost: 52.729847, Optimizer: SGD
# Epoch 800, Cost: 51.694194, Optimizer: SGD
# Epoch 900, Cost: 49.014852, Optimizer: SGD
# Epoch 1000, Cost: 47.019916, Optimizer: SGD
# Params={'window_size': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=5.1041e+01
# Epoch 100, Cost: 6.937745, Optimizer: ADAM
# Epoch 200, Cost: 1.219240, Optimizer: ADAM
# Epoch 300, Cost: 0.499781, Optimizer: ADAM
# Epoch 400, Cost: 0.301902, Optimizer: ADAM
# Epoch 500, Cost: 0.239438, Optimizer: ADAM
# Epoch 600, Cost: 0.197380, Optimizer: ADAM
# Epoch 700, Cost: 0.165343, Optimizer: ADAM
# Epoch 800, Cost: 0.139988, Optimizer: ADAM
# Epoch 900, Cost: 0.119256, Optimizer: ADAM
# Epoch 1000, Cost: 0.101271, Optimizer: ADAM
# Params={'window_size': 10, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=1.0268e-01
# Epoch 100, Cost: 154.827966, Optimizer: SGD
# Epoch 200, Cost: 74.017447, Optimizer: SGD
# Epoch 300, Cost: 72.345826, Optimizer: SGD
# Epoch 400, Cost: 72.316425, Optimizer: SGD
# Epoch 500, Cost: 72.315908, Optimizer: SGD
# Epoch 600, Cost: 72.315899, Optimizer: SGD
# Epoch 700, Cost: 72.315899, Optimizer: SGD
# Epoch 800, Cost: 72.315899, Optimizer: SGD
# Epoch 900, Cost: 72.315899, Optimizer: SGD
# Epoch 1000, Cost: 72.315899, Optimizer: SGD
# Params={'window_size': 10, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=7.0822e+01
# Epoch 100, Cost: 0.367326, Optimizer: ADAM
# Epoch 200, Cost: 0.121779, Optimizer: ADAM
# Epoch 300, Cost: 0.087140, Optimizer: ADAM
# Epoch 400, Cost: 0.068181, Optimizer: ADAM
# Epoch 500, Cost: 0.054858, Optimizer: ADAM
# Epoch 600, Cost: 0.045489, Optimizer: ADAM
# Epoch 700, Cost: 0.038643, Optimizer: ADAM
# Epoch 800, Cost: 0.033352, Optimizer: ADAM
# Epoch 900, Cost: 0.029204, Optimizer: ADAM
# Epoch 1000, Cost: 0.025912, Optimizer: ADAM
# Params={'window_size': 10, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=2.5647e-02
# Epoch 100, Cost: 204.392799, Optimizer: SGD
# Epoch 200, Cost: 163.485829, Optimizer: SGD
# Epoch 300, Cost: 133.399829, Optimizer: SGD
# Epoch 400, Cost: 113.531505, Optimizer: SGD
# Epoch 500, Cost: 99.882667, Optimizer: SGD
# Epoch 600, Cost: 60.731402, Optimizer: SGD
# Epoch 700, Cost: 54.850454, Optimizer: SGD
# Epoch 800, Cost: 85.932206, Optimizer: SGD
# Epoch 900, Cost: 48.154197, Optimizer: SGD
# Epoch 1000, Cost: 49.996688, Optimizer: SGD
# Params={'window_size': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=4.7702e+01
# Epoch 100, Cost: 4.450695, Optimizer: ADAM
# Epoch 200, Cost: 0.938522, Optimizer: ADAM
# Epoch 300, Cost: 0.259844, Optimizer: ADAM
# Epoch 400, Cost: 0.142308, Optimizer: ADAM
# Epoch 500, Cost: 0.092321, Optimizer: ADAM
# Epoch 600, Cost: 0.068623, Optimizer: ADAM
# Epoch 700, Cost: 0.055020, Optimizer: ADAM
# Epoch 800, Cost: 0.045733, Optimizer: ADAM
# Epoch 900, Cost: 0.038429, Optimizer: ADAM
# Epoch 1000, Cost: 0.032169, Optimizer: ADAM
# Params={'window_size': 10, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=3.3685e-02
# /tmp/ipykernel_5213/650291816.py:35: RuntimeWarning: overflow encountered in matmul
#   self.z2 = self.a1 @ self.W2 + self.b2
# /tmp/ipykernel_5213/650291816.py:52: RuntimeWarning: invalid value encountered in matmul
#   grad_W2 = (self.a1.T @ error2) / m
# /tmp/ipykernel_5213/650291816.py:56: RuntimeWarning: invalid value encountered in matmul
#   error1 = (error2 @ self.W2.T) * self.ReLU_deriv(self.z1)
# /tmp/ipykernel_5213/650291816.py:56: RuntimeWarning: invalid value encountered in multiply
#   error1 = (error2 @ self.W2.T) * self.ReLU_deriv(self.z1)
# /tmp/ipykernel_5213/650291816.py:31: RuntimeWarning: invalid value encountered in matmul
#   self.z1 = x @ self.W1 + self.b1
# Epoch 100, Cost: nan, Optimizer: SGD
# Epoch 200, Cost: nan, Optimizer: SGD
# Epoch 300, Cost: nan, Optimizer: SGD
# Epoch 400, Cost: nan, Optimizer: SGD
# Epoch 500, Cost: nan, Optimizer: SGD
# Epoch 600, Cost: nan, Optimizer: SGD
# Epoch 700, Cost: nan, Optimizer: SGD
# Epoch 800, Cost: nan, Optimizer: SGD
# Epoch 900, Cost: nan, Optimizer: SGD
# Epoch 1000, Cost: nan, Optimizer: SGD
# Params={'window_size': 10, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=nan
# Epoch 100, Cost: 0.248264, Optimizer: ADAM
# Epoch 200, Cost: 0.091153, Optimizer: ADAM
# Epoch 300, Cost: 0.059121, Optimizer: ADAM
# Epoch 400, Cost: 0.041091, Optimizer: ADAM
# Epoch 500, Cost: 0.030675, Optimizer: ADAM
# Epoch 600, Cost: 0.023162, Optimizer: ADAM
# Epoch 700, Cost: 0.017833, Optimizer: ADAM
# Epoch 800, Cost: 0.015849, Optimizer: ADAM
# Epoch 900, Cost: 0.070380, Optimizer: ADAM
# Epoch 1000, Cost: 0.008634, Optimizer: ADAM
# Params={'window_size': 10, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=9.2254e-03
# Epoch 100, Cost: 215.958422, Optimizer: SGD
# Epoch 200, Cost: 170.699890, Optimizer: SGD
# Epoch 300, Cost: 103.013416, Optimizer: SGD
# Epoch 400, Cost: 121.239641, Optimizer: SGD
# Epoch 500, Cost: 106.125868, Optimizer: SGD
# Epoch 600, Cost: 63.536670, Optimizer: SGD
# Epoch 700, Cost: 57.228339, Optimizer: SGD
# Epoch 800, Cost: 58.466265, Optimizer: SGD
# Epoch 900, Cost: 56.780457, Optimizer: SGD
# Epoch 1000, Cost: 45.936552, Optimizer: SGD
# Params={'window_size': 10, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=5.8471e+01
# Epoch 100, Cost: 2.266509, Optimizer: ADAM
# Epoch 200, Cost: 0.294179, Optimizer: ADAM
# Epoch 300, Cost: 0.073879, Optimizer: ADAM
# Epoch 400, Cost: 0.032272, Optimizer: ADAM
# Epoch 500, Cost: 0.020401, Optimizer: ADAM
# Epoch 600, Cost: 0.015381, Optimizer: ADAM
# Epoch 700, Cost: 0.012379, Optimizer: ADAM
# Epoch 800, Cost: 0.010418, Optimizer: ADAM
# Epoch 900, Cost: 0.009032, Optimizer: ADAM
# Epoch 1000, Cost: 0.008113, Optimizer: ADAM
# Params={'window_size': 10, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=8.2893e-03
# /tmp/ipykernel_5213/650291816.py:52: RuntimeWarning: overflow encountered in matmul
#   grad_W2 = (self.a1.T @ error2) / m
# /tmp/ipykernel_5213/650291816.py:56: RuntimeWarning: overflow encountered in matmul
#   error1 = (error2 @ self.W2.T) * self.ReLU_deriv(self.z1)
# Epoch 100, Cost: nan, Optimizer: SGD
# Epoch 200, Cost: nan, Optimizer: SGD
# Epoch 300, Cost: nan, Optimizer: SGD
# Epoch 400, Cost: nan, Optimizer: SGD
# Epoch 500, Cost: nan, Optimizer: SGD
# Epoch 600, Cost: nan, Optimizer: SGD
# Epoch 700, Cost: nan, Optimizer: SGD
# Epoch 800, Cost: nan, Optimizer: SGD
# Epoch 900, Cost: nan, Optimizer: SGD
# Epoch 1000, Cost: nan, Optimizer: SGD
# Params={'window_size': 10, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=nan
# Epoch 100, Cost: 0.144236, Optimizer: ADAM
# Epoch 200, Cost: 0.068984, Optimizer: ADAM
# Epoch 300, Cost: 0.037640, Optimizer: ADAM
# Epoch 400, Cost: 0.020076, Optimizer: ADAM
# Epoch 500, Cost: 0.011765, Optimizer: ADAM
# Epoch 600, Cost: 0.008723, Optimizer: ADAM
# Epoch 700, Cost: 0.006297, Optimizer: ADAM
# Epoch 800, Cost: 0.012917, Optimizer: ADAM
# Epoch 900, Cost: 0.004740, Optimizer: ADAM
# Epoch 1000, Cost: 0.003945, Optimizer: ADAM
# Params={'window_size': 10, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=4.1551e-03
# Epoch 100, Cost: 208.556692, Optimizer: SGD
# Epoch 200, Cost: 163.598681, Optimizer: SGD
# Epoch 300, Cost: 135.097368, Optimizer: SGD
# Epoch 400, Cost: 115.042203, Optimizer: SGD
# Epoch 500, Cost: 100.937804, Optimizer: SGD
# Epoch 600, Cost: 91.486750, Optimizer: SGD
# Epoch 700, Cost: 85.153396, Optimizer: SGD
# Epoch 800, Cost: 80.891762, Optimizer: SGD
# Epoch 900, Cost: 50.000943, Optimizer: SGD
# Epoch 1000, Cost: 29.690048, Optimizer: SGD
# Params={'window_size': 15, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=2.4726e+01
# Epoch 100, Cost: 9.304801, Optimizer: ADAM
# Epoch 200, Cost: 1.752223, Optimizer: ADAM
# Epoch 300, Cost: 0.686526, Optimizer: ADAM
# Epoch 400, Cost: 0.455497, Optimizer: ADAM
# Epoch 500, Cost: 0.346389, Optimizer: ADAM
# Epoch 600, Cost: 0.270089, Optimizer: ADAM
# Epoch 700, Cost: 0.214289, Optimizer: ADAM
# Epoch 800, Cost: 0.173921, Optimizer: ADAM
# Epoch 900, Cost: 0.146344, Optimizer: ADAM
# Epoch 1000, Cost: 0.127200, Optimizer: ADAM
# Params={'window_size': 15, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=1.2954e-01
# Epoch 100, Cost: 125377.329427, Optimizer: SGD
# Epoch 200, Cost: 2276.157988, Optimizer: SGD
# Epoch 300, Cost: 111.061157, Optimizer: SGD
# Epoch 400, Cost: 72.981550, Optimizer: SGD
# Epoch 500, Cost: 72.311808, Optimizer: SGD
# Epoch 600, Cost: 72.300028, Optimizer: SGD
# Epoch 700, Cost: 72.299821, Optimizer: SGD
# Epoch 800, Cost: 72.299818, Optimizer: SGD
# Epoch 900, Cost: 72.299817, Optimizer: SGD
# Epoch 1000, Cost: 72.299817, Optimizer: SGD
# Params={'window_size': 15, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=7.0787e+01
# Epoch 100, Cost: 0.409207, Optimizer: ADAM
# Epoch 200, Cost: 0.115895, Optimizer: ADAM
# Epoch 300, Cost: 0.070699, Optimizer: ADAM
# Epoch 400, Cost: 0.050202, Optimizer: ADAM
# Epoch 500, Cost: 0.034313, Optimizer: ADAM
# Epoch 600, Cost: 0.023847, Optimizer: ADAM
# Epoch 700, Cost: 0.018797, Optimizer: ADAM
# Epoch 800, Cost: 0.016989, Optimizer: ADAM
# Epoch 900, Cost: 0.013413, Optimizer: ADAM
# Epoch 1000, Cost: 0.014834, Optimizer: ADAM
# Params={'window_size': 15, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=1.6860e-02
# Epoch 100, Cost: 211.802518, Optimizer: SGD
# Epoch 200, Cost: 167.939796, Optimizer: SGD
# Epoch 300, Cost: 136.386779, Optimizer: SGD
# Epoch 400, Cost: 115.242557, Optimizer: SGD
# Epoch 500, Cost: 101.393087, Optimizer: SGD
# Epoch 600, Cost: 92.193828, Optimizer: SGD
# Epoch 700, Cost: 85.629714, Optimizer: SGD
# Epoch 800, Cost: 81.231661, Optimizer: SGD
# Epoch 900, Cost: 78.284657, Optimizer: SGD
# Epoch 1000, Cost: 76.309947, Optimizer: SGD
# Params={'window_size': 15, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=7.5067e+01
# Epoch 100, Cost: 3.458447, Optimizer: ADAM
# Epoch 200, Cost: 0.476162, Optimizer: ADAM
# Epoch 300, Cost: 0.189146, Optimizer: ADAM
# Epoch 400, Cost: 0.113157, Optimizer: ADAM
# Epoch 500, Cost: 0.081313, Optimizer: ADAM
# Epoch 600, Cost: 0.064032, Optimizer: ADAM
# Epoch 700, Cost: 0.052766, Optimizer: ADAM
# Epoch 800, Cost: 0.044775, Optimizer: ADAM
# Epoch 900, Cost: 0.038899, Optimizer: ADAM
# Epoch 1000, Cost: 0.034370, Optimizer: ADAM
# Params={'window_size': 15, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=3.6405e-02
# Epoch 100, Cost: 3218.730662, Optimizer: SGD
# Epoch 200, Cost: 67239.608312, Optimizer: SGD
# Epoch 300, Cost: 1253.634853, Optimizer: SGD
# Epoch 400, Cost: 93.077075, Optimizer: SGD
# Epoch 500, Cost: 72.665247, Optimizer: SGD
# Epoch 600, Cost: 72.306245, Optimizer: SGD
# Epoch 700, Cost: 72.299931, Optimizer: SGD
# Epoch 800, Cost: 72.299819, Optimizer: SGD
# Epoch 900, Cost: 72.299818, Optimizer: SGD
# Epoch 1000, Cost: 72.299817, Optimizer: SGD
# Params={'window_size': 15, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=7.0787e+01
# Epoch 100, Cost: 0.250486, Optimizer: ADAM
# Epoch 200, Cost: 0.077243, Optimizer: ADAM
# Epoch 300, Cost: 0.041173, Optimizer: ADAM
# Epoch 400, Cost: 0.027272, Optimizer: ADAM
# Epoch 500, Cost: 0.756310, Optimizer: ADAM
# Epoch 600, Cost: 0.015492, Optimizer: ADAM
# Epoch 700, Cost: 0.012376, Optimizer: ADAM
# Epoch 800, Cost: 0.011288, Optimizer: ADAM
# Epoch 900, Cost: 0.009229, Optimizer: ADAM
# Epoch 1000, Cost: 0.007974, Optimizer: ADAM
# Params={'window_size': 15, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=8.1605e-03
# Epoch 100, Cost: 217.779081, Optimizer: SGD
# Epoch 200, Cost: 174.732805, Optimizer: SGD
# Epoch 300, Cost: 144.042723, Optimizer: SGD
# Epoch 400, Cost: 121.885569, Optimizer: SGD
# Epoch 500, Cost: 107.210434, Optimizer: SGD
# Epoch 600, Cost: 95.895742, Optimizer: SGD
# Epoch 700, Cost: 59.135672, Optimizer: SGD
# Epoch 800, Cost: 68.908963, Optimizer: SGD
# Epoch 900, Cost: 53.892771, Optimizer: SGD
# Epoch 1000, Cost: 46.888447, Optimizer: SGD
# Params={'window_size': 15, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=4.8388e+01
# Epoch 100, Cost: 1.788292, Optimizer: ADAM
# Epoch 200, Cost: 0.215506, Optimizer: ADAM
# Epoch 300, Cost: 0.084083, Optimizer: ADAM
# Epoch 400, Cost: 0.044314, Optimizer: ADAM
# Epoch 500, Cost: 0.030634, Optimizer: ADAM
# Epoch 600, Cost: 0.024279, Optimizer: ADAM
# Epoch 700, Cost: 0.020065, Optimizer: ADAM
# Epoch 800, Cost: 0.017533, Optimizer: ADAM
# Epoch 900, Cost: 0.015782, Optimizer: ADAM
# Epoch 1000, Cost: 0.014456, Optimizer: ADAM
# Params={'window_size': 15, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=1.4838e-02
# Epoch 100, Cost: nan, Optimizer: SGD
# Epoch 200, Cost: nan, Optimizer: SGD
# Epoch 300, Cost: nan, Optimizer: SGD
# Epoch 400, Cost: nan, Optimizer: SGD
# Epoch 500, Cost: nan, Optimizer: SGD
# Epoch 600, Cost: nan, Optimizer: SGD
# Epoch 700, Cost: nan, Optimizer: SGD
# Epoch 800, Cost: nan, Optimizer: SGD
# Epoch 900, Cost: nan, Optimizer: SGD
# Epoch 1000, Cost: nan, Optimizer: SGD
# Params={'window_size': 15, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=nan
# Epoch 100, Cost: 0.135057, Optimizer: ADAM
# Epoch 200, Cost: 0.038735, Optimizer: ADAM
# Epoch 300, Cost: 0.021925, Optimizer: ADAM
# Epoch 400, Cost: 0.076007, Optimizer: ADAM
# Epoch 500, Cost: 0.010451, Optimizer: ADAM
# Epoch 600, Cost: 0.072116, Optimizer: ADAM
# Epoch 700, Cost: 0.005988, Optimizer: ADAM
# Epoch 800, Cost: 0.025202, Optimizer: ADAM
# Epoch 900, Cost: 0.004382, Optimizer: ADAM
# Epoch 1000, Cost: 0.049628, Optimizer: ADAM
# Params={'window_size': 15, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=9.3469e-02
# Epoch 100, Cost: 206.691223, Optimizer: SGD
# Epoch 200, Cost: 164.082373, Optimizer: SGD
# Epoch 300, Cost: 135.116029, Optimizer: SGD
# Epoch 400, Cost: 114.802488, Optimizer: SGD
# Epoch 500, Cost: 100.772749, Optimizer: SGD
# Epoch 600, Cost: 91.657264, Optimizer: SGD
# Epoch 700, Cost: 85.262131, Optimizer: SGD
# Epoch 800, Cost: 80.979330, Optimizer: SGD
# Epoch 900, Cost: 47.584678, Optimizer: SGD
# Epoch 1000, Cost: 18.626304, Optimizer: SGD
# Params={'window_size': 20, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=2.2564e+01
# Epoch 100, Cost: 7.316935, Optimizer: ADAM
# Epoch 200, Cost: 0.703054, Optimizer: ADAM
# Epoch 300, Cost: 0.341411, Optimizer: ADAM
# Epoch 400, Cost: 0.252279, Optimizer: ADAM
# Epoch 500, Cost: 0.203328, Optimizer: ADAM
# Epoch 600, Cost: 0.167825, Optimizer: ADAM
# Epoch 700, Cost: 0.137935, Optimizer: ADAM
# Epoch 800, Cost: 0.112249, Optimizer: ADAM
# Epoch 900, Cost: 0.088609, Optimizer: ADAM
# Epoch 1000, Cost: 0.072777, Optimizer: ADAM
# Params={'window_size': 20, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=7.7200e-02
# Epoch 100, Cost: 79.860516, Optimizer: SGD
# Epoch 200, Cost: 72.323774, Optimizer: SGD
# Epoch 300, Cost: 72.190793, Optimizer: SGD
# Epoch 400, Cost: 72.188239, Optimizer: SGD
# Epoch 500, Cost: 72.188001, Optimizer: SGD
# Epoch 600, Cost: 72.187830, Optimizer: SGD
# Epoch 700, Cost: 72.187667, Optimizer: SGD
# Epoch 800, Cost: 72.187507, Optimizer: SGD
# Epoch 900, Cost: 72.187350, Optimizer: SGD
# Epoch 1000, Cost: 72.187194, Optimizer: SGD
# Params={'window_size': 20, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=7.0699e+01
# Epoch 100, Cost: 0.260828, Optimizer: ADAM
# Epoch 200, Cost: 0.116679, Optimizer: ADAM
# Epoch 300, Cost: 0.071606, Optimizer: ADAM
# Epoch 400, Cost: 0.050394, Optimizer: ADAM
# Epoch 500, Cost: 0.038426, Optimizer: ADAM
# Epoch 600, Cost: 0.029946, Optimizer: ADAM
# Epoch 700, Cost: 0.023941, Optimizer: ADAM
# Epoch 800, Cost: 0.019568, Optimizer: ADAM
# Epoch 900, Cost: 0.020052, Optimizer: ADAM
# Epoch 1000, Cost: 0.015310, Optimizer: ADAM
# Params={'window_size': 20, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=1.6630e-02
# Epoch 100, Cost: 212.814490, Optimizer: SGD
# Epoch 200, Cost: 169.946039, Optimizer: SGD
# Epoch 300, Cost: 137.713596, Optimizer: SGD
# Epoch 400, Cost: 116.473505, Optimizer: SGD
# Epoch 500, Cost: 102.374210, Optimizer: SGD
# Epoch 600, Cost: 92.780891, Optimizer: SGD
# Epoch 700, Cost: 57.835654, Optimizer: SGD
# Epoch 800, Cost: 55.421997, Optimizer: SGD
# Epoch 900, Cost: 48.474446, Optimizer: SGD
# Epoch 1000, Cost: 37.832460, Optimizer: SGD
# Params={'window_size': 20, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=3.9620e+01
# Epoch 100, Cost: 2.061267, Optimizer: ADAM
# Epoch 200, Cost: 0.306216, Optimizer: ADAM
# Epoch 300, Cost: 0.194293, Optimizer: ADAM
# Epoch 400, Cost: 0.138694, Optimizer: ADAM
# Epoch 500, Cost: 0.092464, Optimizer: ADAM
# Epoch 600, Cost: 0.064783, Optimizer: ADAM
# Epoch 700, Cost: 0.050948, Optimizer: ADAM
# Epoch 800, Cost: 0.042121, Optimizer: ADAM
# Epoch 900, Cost: 0.035468, Optimizer: ADAM
# Epoch 1000, Cost: 0.030386, Optimizer: ADAM
# Params={'window_size': 20, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=3.1404e-02
# Epoch 100, Cost: nan, Optimizer: SGD
# Epoch 200, Cost: nan, Optimizer: SGD
# Epoch 300, Cost: nan, Optimizer: SGD
# Epoch 400, Cost: nan, Optimizer: SGD
# Epoch 500, Cost: nan, Optimizer: SGD
# Epoch 600, Cost: nan, Optimizer: SGD
# Epoch 700, Cost: nan, Optimizer: SGD
# Epoch 800, Cost: nan, Optimizer: SGD
# Epoch 900, Cost: nan, Optimizer: SGD
# Epoch 1000, Cost: nan, Optimizer: SGD
# Params={'window_size': 20, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=nan
# Epoch 100, Cost: 0.180335, Optimizer: ADAM
# Epoch 200, Cost: 0.052319, Optimizer: ADAM
# Epoch 300, Cost: 0.027243, Optimizer: ADAM
# Epoch 400, Cost: 0.018965, Optimizer: ADAM
# Epoch 500, Cost: 0.012531, Optimizer: ADAM
# Epoch 600, Cost: 0.057746, Optimizer: ADAM
# Epoch 700, Cost: 0.008579, Optimizer: ADAM
# Epoch 800, Cost: 0.007058, Optimizer: ADAM
# Epoch 900, Cost: 0.041403, Optimizer: ADAM
# Epoch 1000, Cost: 0.006883, Optimizer: ADAM
# Params={'window_size': 20, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=7.7072e-03
# Epoch 100, Cost: 221.558054, Optimizer: SGD
# Epoch 200, Cost: 177.085064, Optimizer: SGD
# Epoch 300, Cost: 144.079985, Optimizer: SGD
# Epoch 400, Cost: 120.755452, Optimizer: SGD
# Epoch 500, Cost: 105.323510, Optimizer: SGD
# Epoch 600, Cost: 95.025391, Optimizer: SGD
# Epoch 700, Cost: 56.311273, Optimizer: SGD
# Epoch 800, Cost: 55.539857, Optimizer: SGD
# Epoch 900, Cost: 51.367463, Optimizer: SGD
# Epoch 1000, Cost: 51.715838, Optimizer: SGD
# Params={'window_size': 20, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=6.3282e+01
# Epoch 100, Cost: 1.612521, Optimizer: ADAM
# Epoch 200, Cost: 0.259104, Optimizer: ADAM
# Epoch 300, Cost: 0.046671, Optimizer: ADAM
# Epoch 400, Cost: 0.025885, Optimizer: ADAM
# Epoch 500, Cost: 0.018308, Optimizer: ADAM
# Epoch 600, Cost: 0.014831, Optimizer: ADAM
# Epoch 700, Cost: 0.013042, Optimizer: ADAM
# Epoch 800, Cost: 0.011725, Optimizer: ADAM
# Epoch 900, Cost: 0.010653, Optimizer: ADAM
# Epoch 1000, Cost: 0.009783, Optimizer: ADAM
# Params={'window_size': 20, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=1.0316e-02
# /tmp/ipykernel_5213/650291816.py:35: RuntimeWarning: invalid value encountered in matmul
#   self.z2 = self.a1 @ self.W2 + self.b2
# Epoch 100, Cost: nan, Optimizer: SGD
# Epoch 200, Cost: nan, Optimizer: SGD
# Epoch 300, Cost: nan, Optimizer: SGD
# Epoch 400, Cost: nan, Optimizer: SGD
# Epoch 500, Cost: nan, Optimizer: SGD
# Epoch 600, Cost: nan, Optimizer: SGD
# Epoch 700, Cost: nan, Optimizer: SGD
# Epoch 800, Cost: nan, Optimizer: SGD
# Epoch 900, Cost: nan, Optimizer: SGD
# Epoch 1000, Cost: nan, Optimizer: SGD
# Params={'window_size': 20, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=nan
# Epoch 100, Cost: 0.147128, Optimizer: ADAM
# Epoch 200, Cost: 0.042060, Optimizer: ADAM
# Epoch 300, Cost: 0.020796, Optimizer: ADAM
# Epoch 400, Cost: 0.012305, Optimizer: ADAM
# Epoch 500, Cost: 0.012706, Optimizer: ADAM
# Epoch 600, Cost: 0.006297, Optimizer: ADAM
# Epoch 700, Cost: 0.004755, Optimizer: ADAM
# Epoch 800, Cost: 0.058560, Optimizer: ADAM
# Epoch 900, Cost: 0.004818, Optimizer: ADAM
# Epoch 1000, Cost: 0.003597, Optimizer: ADAM
# Params={'window_size': 20, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=4.3314e-03
# Epoch 100, Cost: 220.979132, Optimizer: SGD
# Epoch 200, Cost: 171.897539, Optimizer: SGD
# Epoch 300, Cost: 139.010340, Optimizer: SGD
# Epoch 400, Cost: 116.974220, Optimizer: SGD
# Epoch 500, Cost: 102.208882, Optimizer: SGD
# Epoch 600, Cost: 92.315343, Optimizer: SGD
# Epoch 700, Cost: 85.686162, Optimizer: SGD
# Epoch 800, Cost: 81.244268, Optimizer: SGD
# Epoch 900, Cost: 78.267970, Optimizer: SGD
# Epoch 1000, Cost: 76.273696, Optimizer: SGD
# Params={'window_size': 30, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=7.5103e+01
# Epoch 100, Cost: 5.530536, Optimizer: ADAM
# Epoch 200, Cost: 0.878024, Optimizer: ADAM
# Epoch 300, Cost: 0.459351, Optimizer: ADAM
# Epoch 400, Cost: 0.331803, Optimizer: ADAM
# Epoch 500, Cost: 0.265998, Optimizer: ADAM
# Epoch 600, Cost: 0.221720, Optimizer: ADAM
# Epoch 700, Cost: 0.189601, Optimizer: ADAM
# Epoch 800, Cost: 0.162764, Optimizer: ADAM
# Epoch 900, Cost: 0.137488, Optimizer: ADAM
# Epoch 1000, Cost: 0.121305, Optimizer: ADAM
# Params={'window_size': 30, 'hidden_size': 50, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=1.3637e-01
# Epoch 100, Cost: 15027119037.180729, Optimizer: SGD
# Epoch 200, Cost: 264296238.217260, Optimizer: SGD
# Epoch 300, Cost: 4648499.079362, Optimizer: SGD
# Epoch 400, Cost: 81828.507108, Optimizer: SGD
# Epoch 500, Cost: 1510.148918, Optimizer: SGD
# Epoch 600, Cost: 97.513922, Optimizer: SGD
# Epoch 700, Cost: 72.668573, Optimizer: SGD
# Epoch 800, Cost: 72.231595, Optimizer: SGD
# Epoch 900, Cost: 72.223909, Optimizer: SGD
# Epoch 1000, Cost: 72.223774, Optimizer: SGD
# Params={'window_size': 30, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=7.0814e+01
# Epoch 100, Cost: 0.276159, Optimizer: ADAM
# Epoch 200, Cost: 0.130798, Optimizer: ADAM
# Epoch 300, Cost: 0.080566, Optimizer: ADAM
# Epoch 400, Cost: 0.057989, Optimizer: ADAM
# Epoch 500, Cost: 0.874462, Optimizer: ADAM
# Epoch 600, Cost: 0.033618, Optimizer: ADAM
# Epoch 700, Cost: 0.026379, Optimizer: ADAM
# Epoch 800, Cost: 0.505744, Optimizer: ADAM
# Epoch 900, Cost: 0.018716, Optimizer: ADAM
# Epoch 1000, Cost: 0.015852, Optimizer: ADAM
# Params={'window_size': 30, 'hidden_size': 50, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=2.0168e-02
# Epoch 100, Cost: 218.639804, Optimizer: SGD
# Epoch 200, Cost: 171.220864, Optimizer: SGD
# Epoch 300, Cost: 140.969505, Optimizer: SGD
# Epoch 400, Cost: 119.632686, Optimizer: SGD
# Epoch 500, Cost: 104.280036, Optimizer: SGD
# Epoch 600, Cost: 93.703108, Optimizer: SGD
# Epoch 700, Cost: 86.616014, Optimizer: SGD
# Epoch 800, Cost: 81.867288, Optimizer: SGD
# Epoch 900, Cost: 78.685389, Optimizer: SGD
# Epoch 1000, Cost: 76.553344, Optimizer: SGD
# Params={'window_size': 30, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=7.5377e+01
# Epoch 100, Cost: 1.821029, Optimizer: ADAM
# Epoch 200, Cost: 0.345399, Optimizer: ADAM
# Epoch 300, Cost: 0.179267, Optimizer: ADAM
# Epoch 400, Cost: 0.122461, Optimizer: ADAM
# Epoch 500, Cost: 0.069044, Optimizer: ADAM
# Epoch 600, Cost: 0.048016, Optimizer: ADAM
# Epoch 700, Cost: 0.039127, Optimizer: ADAM
# Epoch 800, Cost: 0.033963, Optimizer: ADAM
# Epoch 900, Cost: 0.030192, Optimizer: ADAM
# Epoch 1000, Cost: 0.027052, Optimizer: ADAM
# Params={'window_size': 30, 'hidden_size': 100, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=3.2508e-02
# Epoch 100, Cost: 256.136283, Optimizer: SGD
# Epoch 200, Cost: 75.458415, Optimizer: SGD
# Epoch 300, Cost: 72.280662, Optimizer: SGD
# Epoch 400, Cost: 72.224772, Optimizer: SGD
# Epoch 500, Cost: 72.223789, Optimizer: SGD
# Epoch 600, Cost: 72.223772, Optimizer: SGD
# Epoch 700, Cost: 72.223772, Optimizer: SGD
# Epoch 800, Cost: 72.223772, Optimizer: SGD
# Epoch 900, Cost: 72.223772, Optimizer: SGD
# Epoch 1000, Cost: 72.223772, Optimizer: SGD
# Params={'window_size': 30, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=7.0815e+01
# Epoch 100, Cost: 0.110336, Optimizer: ADAM
# Epoch 200, Cost: 0.071436, Optimizer: ADAM
# Epoch 300, Cost: 0.034469, Optimizer: ADAM
# Epoch 400, Cost: 0.114574, Optimizer: ADAM
# Epoch 500, Cost: 0.016289, Optimizer: ADAM
# Epoch 600, Cost: 0.011286, Optimizer: ADAM
# Epoch 700, Cost: 0.008669, Optimizer: ADAM
# Epoch 800, Cost: 0.014171, Optimizer: ADAM
# Epoch 900, Cost: 0.006622, Optimizer: ADAM
# Epoch 1000, Cost: 0.006373, Optimizer: ADAM
# Params={'window_size': 30, 'hidden_size': 100, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=8.8126e-03
# Epoch 100, Cost: 221.922833, Optimizer: SGD
# Epoch 200, Cost: 181.418226, Optimizer: SGD
# Epoch 300, Cost: 146.896421, Optimizer: SGD
# Epoch 400, Cost: 122.258114, Optimizer: SGD
# Epoch 500, Cost: 106.398316, Optimizer: SGD
# Epoch 600, Cost: 95.386389, Optimizer: SGD
# Epoch 700, Cost: 87.743893, Optimizer: SGD
# Epoch 800, Cost: 82.623019, Optimizer: SGD
# Epoch 900, Cost: 52.691716, Optimizer: SGD
# Epoch 1000, Cost: 50.455785, Optimizer: SGD
# Params={'window_size': 30, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'sgd'}  →  Val MSE=5.2615e+01
# Epoch 100, Cost: 1.154713, Optimizer: ADAM
# Epoch 200, Cost: 0.291213, Optimizer: ADAM
# Epoch 300, Cost: 0.147385, Optimizer: ADAM
# Epoch 400, Cost: 0.102430, Optimizer: ADAM
# Epoch 500, Cost: 0.075558, Optimizer: ADAM
# Epoch 600, Cost: 0.053353, Optimizer: ADAM
# Epoch 700, Cost: 0.032201, Optimizer: ADAM
# Epoch 800, Cost: 0.020938, Optimizer: ADAM
# Epoch 900, Cost: 0.015814, Optimizer: ADAM
# Epoch 1000, Cost: 0.012866, Optimizer: ADAM
# Params={'window_size': 30, 'hidden_size': 200, 'learning_rate': 0.001, 'optimizer': 'adam'}  →  Val MSE=1.7116e-02
# Epoch 100, Cost: nan, Optimizer: SGD
# Epoch 200, Cost: nan, Optimizer: SGD
# Epoch 300, Cost: nan, Optimizer: SGD
# Epoch 400, Cost: nan, Optimizer: SGD
# Epoch 500, Cost: nan, Optimizer: SGD
# Epoch 600, Cost: nan, Optimizer: SGD
# Epoch 700, Cost: nan, Optimizer: SGD
# Epoch 800, Cost: nan, Optimizer: SGD
# Epoch 900, Cost: nan, Optimizer: SGD
# Epoch 1000, Cost: nan, Optimizer: SGD
# Params={'window_size': 30, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'sgd'}  →  Val MSE=nan
# Epoch 100, Cost: 0.121699, Optimizer: ADAM
# Epoch 200, Cost: 0.023264, Optimizer: ADAM
# Epoch 300, Cost: 0.014382, Optimizer: ADAM
# Epoch 400, Cost: 0.010811, Optimizer: ADAM
# Epoch 500, Cost: 0.009840, Optimizer: ADAM
# Epoch 600, Cost: 0.007356, Optimizer: ADAM
# Epoch 700, Cost: 0.005943, Optimizer: ADAM
# Epoch 800, Cost: 0.801534, Optimizer: ADAM
# Epoch 900, Cost: 0.005932, Optimizer: ADAM
# Epoch 1000, Cost: 0.004623, Optimizer: ADAM
# Params={'window_size': 30, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'adam'}  →  Val MSE=6.4907e-03
#
# Best params: {'window_size': 10, 'hidden_size': 200, 'learning_rate': 0.01, 'optimizer': 'adam'}
# Best validation MSE: 0.004155133147746571

# %%
X_trainval, y_trainval = make_windows(trajectory[:n_train+n_val], best_params['window_size'])
X_test_w,   y_test_w   = make_windows(trajectory[n_train+n_val:], best_params['window_size'])

X_trainval = (X_trainval - Xmu) / Xstd
y_trainval = (y_trainval - ymu) / ystd

X_test_w = (X_test_w - Xmu) / Xstd
y_test_w = (y_test_w - ymu) / ystd

final_model = NeuralNetwork(
    input_size  = best_params['window_size'] * 3,
    hidden_size = best_params['hidden_size'],
    learning_rate = best_params['learning_rate'],
    epochs      = best_params['epochs'],
    output_size = 3
)

final_hist = final_model.train(
    X_trainval, y_trainval,
    optimizer   = best_params['optimizer']    
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[18], line 4
#       1 X_trainval, y_trainval = make_windows(trajectory[:n_train+n_val], best_params['window_size'])
#       2 X_test_w,   y_test_w   = make_windows(trajectory[n_train+n_val:], best_params['window_size'])
# ----> 4 X_trainval = (X_trainval - Xmu) / Xstd
#       5 y_trainval = (y_trainval - ymu) / ystd
#       7 X_test_w = (X_test_w - Xmu) / Xstd
#
# ValueError: operands could not be broadcast together with shapes (42473,30) (1,60)

# %%
test_pred = final_model.predict(X_test_w)
test_mse  = np.mean((test_pred - y_test_w)**2)
print("Test MSE:", test_mse)
# Out:
# Test MSE: 3.8572356735380456e-05

# %% [markdown]
# RMSE = 0.074. So, on average, each coorainet is off by ~0.07 units just one time-step (Δt = 0.01) into the future. It captures the immediate local dynamics of a chaotic system with less than a tenth of a unit error

# %% [markdown]
# # Forecasting

# %%
# Parameters
window_size = best_params['window_size']
n_forecast  = 600
coords      = ['x','y','z']
idxs   = [0,1,2]

# Seed window from the held-out test split
L0     = n_train + n_val
window = trajectory[L0 : L0 + window_size].copy()

# %%
# Closed-loop forecast
forecast = np.zeros((n_forecast, 3))

for t in range(n_forecast):
    x_norm = (window.flatten()[None, :] - Xmu) / Xstd
    y_norm = final_model.predict(x_norm)
    y      = (y_norm * ystd + ymu).flatten()
    forecast[t] = y
    window     = np.vstack([window[1:], y])

# Time axes
t_past = np.arange(-window_size, 0)
t_fut  = np.arange(0, n_forecast)

fig, axes = plt.subplots(2, 3, figsize=(18, 8))

for col, (coord, idx) in enumerate(zip(coords, idxs)):
    # Plot 1: True past → True future
    true_past   = trajectory[L0 : L0 + window_size, idx]
    true_future = trajectory[L0 + window_size : L0 + window_size + n_forecast, idx]
    axes[0, col].plot(t_past, true_past, 'o-', label=f"True past ({window_size})")
    axes[0, col].plot(t_fut,  true_future, '-',  label="True future", alpha=0.6)
    axes[0, col].axvline(0, color='k', linestyle='--', lw=1)
    axes[0, col].set_title(f"{coord.upper()}-coord: past → future")
    axes[0, col].set_xlabel("Rel. time step");  axes[0, col].set_ylabel(f"{coord}(t)")
    axes[0, col].legend()

    # Plot 2: Closed-loop forecast vs True
    fcst = forecast[:, idx]
    axes[1, col].plot(t_fut, true_future, label="True future", alpha=0.6)
    axes[1, col].plot(t_fut, fcst, '--', label="Forecast",    alpha=0.8)
    axes[1, col].set_title(f"{coord.upper()}-coord: forecast vs true")
    axes[1, col].set_xlabel("Rel. time step");  axes[1, col].set_ylabel(f"{coord}(t)")
    axes[1, col].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Increasing the Number of POints into the Future we Forecast

# %%
# Parameters
window_size = best_params['window_size']
n_forecast  = 2000
coords      = ['x','y','z']
idxs   = [0,1,2]

# Seed window from the held-out test split
L0     = n_train + n_val
window = trajectory[L0 : L0 + window_size].copy()


# Closed-loop forecast
forecast = np.zeros((n_forecast, 3))

for t in range(n_forecast):
    x_norm = (window.flatten()[None, :] - Xmu) / Xstd
    y_norm = final_model.predict(x_norm)
    y      = (y_norm * ystd + ymu).flatten()
    forecast[t] = y
    window     = np.vstack([window[1:], y])

# Time axes
t_past = np.arange(-window_size, 0)
t_fut  = np.arange(0, n_forecast)

fig, axes = plt.subplots(2, 3, figsize=(18, 8))

for col, (coord, idx) in enumerate(zip(coords, idxs)):
    # Plot 1: True past → True future
    true_past   = trajectory[L0 : L0 + window_size, idx]
    true_future = trajectory[L0 + window_size : L0 + window_size + n_forecast, idx]
    axes[0, col].plot(t_past, true_past, 'o-', label=f"True past ({window_size})")
    axes[0, col].plot(t_fut,  true_future, '-',  label="True future", alpha=0.6)
    axes[0, col].axvline(0, color='k', linestyle='--', lw=1)
    axes[0, col].set_title(f"{coord.upper()}-coord: past → future")
    axes[0, col].set_xlabel("Rel. time step");  axes[0, col].set_ylabel(f"{coord}(t)")
    axes[0, col].legend()

    # Plot 2: Closed-loop forecast vs True
    fcst = forecast[:, idx]
    axes[1, col].plot(t_fut, true_future, label="True future", alpha=0.6)
    axes[1, col].plot(t_fut, fcst, '--', label="Forecast",    alpha=0.8)
    axes[1, col].set_title(f"{coord.upper()}-coord: forecast vs true")
    axes[1, col].set_xlabel("Rel. time step");  axes[1, col].set_ylabel(f"{coord}(t)")
    axes[1, col].legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# RMSE vs horizon for iterative forecasts

# %%
# 1) Define the horizons you want to evaluate
horizons = [1, 2, 3, 5, 10, 20, 40]
iter_rmse = []

# 2) Seed index for the test-split window
L0 = n_train + n_val

# 3) Loop over each horizon
for h in horizons:
    # Start from the last true window
    window = trajectory[L0 : L0 + window_size].copy()
    preds = []
    
    # Closed‐loop forecast for h steps
    for _ in range(h):
        # normalize and predict one step
        x_norm = (window.flatten()[None, :] - Xmu) / Xstd
        y_norm = final_model.predict(x_norm)
        y_pred = (y_norm * ystd + ymu).flatten()
        
        preds.append(y_pred[0])        # x-coordinate
        window = np.vstack([window[1:], y_pred])
    
    # True future x-values
    true_x = trajectory[L0 + window_size : L0 + window_size + h, 0]
    
    # Compute RMSE and store
    rmse = np.sqrt(np.mean((np.array(preds) - true_x)**2))
    iter_rmse.append(rmse)
    print(f"Horizon {h:2d}: RMSE = {rmse:.4f}")

# 4) Plot Horizon vs RMSE
plt.figure(figsize=(6,4))
plt.plot(horizons, iter_rmse, 'o-', linewidth=2)
plt.xlabel("Forecast Horizon (steps ahead)")
plt.ylabel("RMSE of x-coordinate")
plt.title("Iterative (Closed-Loop) Forecast RMSE vs Horizon")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Horizon  1: RMSE = 0.0170
# Horizon  2: RMSE = 0.0161
# Horizon  3: RMSE = 0.0186
# Horizon  5: RMSE = 0.0219
# Horizon 10: RMSE = 0.0273
# Horizon 20: RMSE = 0.0628
# Horizon 40: RMSE = 0.1545
